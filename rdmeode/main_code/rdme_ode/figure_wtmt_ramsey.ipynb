# %% [markdown]
# # WT_MT_Ramsey
# This is the code used for extracting the data from RDME-ODE simulation results for Grep and generating the figures similar to the ones in the Ramsey et al. 2006 paper.

# %%
# %run env.ipynb
import pickle
import os
import numpy as np
from jLM.RDME import File as RDMEFile
import jLM
import json
import matplotlib.pyplot as plt
import seaborn as sns
from traj_analysis_rdme import *
from tqdm import tqdm
import pandas as pd
import logging
# Define directories
wt_traj_dir = "/data2/2024_Yeast_GS/my_current_code/rdme_ode_results/20241107wtmt_ramsey/"
mt_traj_dir = "/data2/2024_Yeast_GS/my_current_code/rdme_ode_results/20250512_MT_1hour"
fig_dir = os.path.join(mt_traj_dir ,'figures_comparison_WTMT/' )

# Configure logging
log_file = os.path.join(fig_dir, 'run_log.log')
if not os.path.exists(fig_dir):
    os.makedirs(fig_dir)

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()
    ]
)

logging.info(f"Starting comparison of WT and MT data in directory: {wt_traj_dir}")

wt_files = [f for f in os.listdir(wt_traj_dir) if f.startswith('yeast1.1')  and 'wt' in f.lower() and f.endswith('.lm')]
mt_files = [f for f in os.listdir(mt_traj_dir) if f.startswith('yeast1.1') and f.endswith('.lm')]
traj_suff = "_ode.jsonl"

logging.info(f"WT files: {wt_traj_dir}")
logging.info(f"MT files: {mt_traj_dir}")
logging.info(f"Final results saved in : {fig_dir}")
# Out:
# <style>
# table.fullWidth {
#     width: 100%;
# }
#
# table.jLMtbl {
#     border: 1px solid #000;
# }
#
# .jLMtbl td, .jLMtbl tr, .jLMtbl th, .diffTbl table, .diffTbl td, .diffTbl tr {
#     border: 0px;
# }
#
# .jLMtbl caption, .diffTbl caption {
#     font-size: 1.5em;
#     font-weight: bold;
#     color: #555;
#     text-align: left;
#     padding: 15px 10px 8px 10px;
# }
#
# .jLMtbl td, .jLMtbl th {
#     padding-left: 10px;
#     padding-right: 10px;
# }
#
# .jLMtbl tr:nth-child(even) { background: #ddd;  }
# .jLMtbl tr:nth-child(odd) { background: #f8f8f8;  }
#
# table.diffTbl {
#     border: 0px;
# }
#
# td.noWrap {
#     white-space:nowrap;
# }
#
# .diffTbl span.rot {
#     -webkit-transform: rotate(-90deg);
#     transform: rotate(-90deg);
#     display: inline-block;
#     white-space: nowrap;
# }
#
# .diffTbl td[rowspan], .diffTbl td[colspan] {
#     background: #fff;
#     font-weight: bold;
# }
#
# .diffTbl td[rowspan] {
#     width: 0.01em;
#     padding: 0em 0.2em;
# }
#
# .diffTbl td {
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     vertical-align: middle;
#     background-color: hsla(0,0%,90%,1);
#     color: #000;
# }
#
#
# .diffTbl td.rhdr {
#     text-align: right;
#     background: #555;
#     color: #fff;
# }
#
# .diffTbl td.units {
#     background: #fff;
#     color: #000;
# }
#
# .diffTbl td.chdr {
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     background: #555;
#     color: #fff;
# }
#
# .diffTbl td.zero {
#     background-color: hsla(180,100%,90%,1);
# }
#
# .diffTbl td.inf {
#     background-color: hsla(0,100%,90%,1);
# }
#
# .diffTbl td.undef {
#     background-color: #f00;
#     color: #fff;
# }
#
#
# .jLMtbl th {
#     border: 0px;
#     background: #555;
#     color: #fff;
# }
#
# .jLMtbl th[scope=col] {
#     height: 40px;
#     text-align: center;
#     vertical-align: middle;
# }
#
# .jLMtbl th[scope=row] {
#     text-align: left;
# }
#
# td.jLMparam{
#     width: 250px;
#     text-align: right;
#     padding-right: 15px;
# }
#
#
# td.rxnCol {
#     text-align: center;
#     width: 333px;
# }
#
# td.objIndex {
#     width: 15px;
#     text-align:center;
#     vertical-align:middle;
# }
#
#
# div.jLMflex {
#     width: 100%;
#     display: flex;
#     margin:0;
# }
#
# div.regRight, div.trajRight {
#     flex-grow: 1;
# }
#
# div.trajRight {
#     padding-top: 20px;
# }
#
# div.regLeft {
#     width:200px;
# }
#
# div.trajLeft {
#     width:400px;
# }
#
# div.jLMx3Dkey {
#     display: block;
#     position: absolute;
#     background-color: rgba(255,255,255,0.8);
#     top: 3px;
#     right: 3px;
#     width: 225px;
#     max-height: 600px;
#     overflow-x: hidden;
#     overflow-y: auto;
#     border: 1px solid #000;
#     padding: 0px;
# }
#
# div.jLMx3Dstandalone {
#     height: 100vh;
#     width: 100vw;
#     overflow: hidden;
# }
#
# div.jLMx3Dkeymin {
#     width: auto;
#     height: auto;
#     display: none;
#     border: 0px;
#     overflow: hidden;
# }
#
# div.jLMx3Dkeyhelp {
#     display: none;
#     position: absolute;
#     background-color: rgba(255,255,255,0.8);
#     bottom: 2px;
#     right: 300px;
#     width: 400px;
#     max-height: 600px;
#     overflow-x: hidden;
#     overflow-y: auto;
#     border: 1px solid #000;
#     padding: 10px;
# }
#
# div.jLMx3Dkeyhelpstandalone {
#     display: none;
#     position: absolute;
#     background-color: rgba(255,255,255,0.8);
#     top: 10px;
#     left: 10px;
#     width: 400px;
#     max-height: 95%;
#     overflow-x: hidden;
#     overflow-y: auto;
#     border: 1px solid #000;
#     padding: 10px;
# }
#
# button.jLMx3Dkey {
#     float: left;
#     margin: 0px;
#     -webkit-transition-duration: 0.4s;
#     transition-duration: 0.4s;
#     background-color: #def1f0;
#     padding: 10px 5px;
#     border: 1px solid #fff;
#     width: 33%;
# }
#
# button.jLMx3Dkey:hover {
#     background-color: #108e88;
#     color: #fff;
# }
#
# button.jLMx3dbtstandalone {
#     display: table-cell;
#     width: 50%;
# }
# button.jLMx3dbt {
#     display: table-cell;
# }
#
# div.jLMx3dbt {
#     display: table;
#     width: 225px;
# }
#
#
# ul.reg {
#     list-style-type: none;
#     width: 100%;
# }
#
# img.smallreg {
#     border:1px solid #000;
#     float: left;
#     image-rendering: -moz-crisp-edges;
#     image-rendering: -o-crisp-edges;
#     image-rendering: -webkit-optimize-contrast;
#     -ms-interpolation-mode: nearest-neighbor;
#     image-rendering: pixelated;
# }
#
# X3D.jLM {
#     width: 100%;
#     height: 90%;
#     border: 0px;
# }
#
# span.jLMparticleKey {
#     position: relative;
#     top: 3px;
#     font-size: 1.5em;
# }
#
# div.jLMbigSps {
#     font-family: serif;
#     background: #fff;
#     color: #000;
#     display: table-cell;
#     vertical-align: middle;
#     text-align: center;
#     height: 70px;
#     font-size: 3.2em;
#     padding: 40px 10px 10px 10px;
#     border: 0px;
# }
#
# input[type=range][orient=vertical].stackSlider {
#     writing-mode: bt-lr; /* IE */
#     display: block;
#     margin: auto;
#     -webkit-appearance: slider-vertical; /* WebKit */
#     width: 8px;
#     height: 250px;
#     padding: 15px;
# }
#
# span.jLMregion {
#     padding: 1px 4px;
#     margin: 2px;
#     display: inline-block;
#     font-family: sans-serif;
#     border: 1px solid black;
# }
#
# span.jLMnum, td.jLMnum {
#     font-family: serif;
#     font-size: 1.2em;
# }
#
# div.jLMdescription {
#     margin: 1em 3em;
#     font-style: italic;
# }</style>
# <script type="text/javascript">
#  var fontawesome_css = document.getElementById("fontawesome-css");
#  if (fontawesome_css === null) {
#     var l = document.createElement("link");
#     l.setAttribute("rel", "stylesheet");
#     l.setAttribute("type", "text/css");
#     l.setAttribute("href", "https://netdna.bootstrapcdn.com/font-awesome/3.2.1/css/font-awesome.css");
#     l.setAttribute("id", "fontawesome-css");
#     $("head").append(l);
# }
# </script>
# 2025-05-12 18:43:39,576 - INFO - Starting comparison of WT and MT data in directory: /data2/2024_Yeast_GS/my_current_code/rdme_ode_results/20241107wtmt_ramsey/
# 2025-05-12 18:43:39,577 - INFO - WT files: /data2/2024_Yeast_GS/my_current_code/rdme_ode_results/20241107wtmt_ramsey/
# 2025-05-12 18:43:39,577 - INFO - MT files: /data2/2024_Yeast_GS/my_current_code/rdme_ode_results/20250512_MT_1hour
# 2025-05-12 18:43:39,578 - INFO - Final results saved in : /data2/2024_Yeast_GS/my_current_code/rdme_ode_results/20250512_MT_1hour/figures_comparison_WTMT/

# %% [markdown]
# default, get data required

# %%
# Initialize dictionaries to store data for each species
wt_species_data = {}
mt_species_data = {}
wt_ode_data = {}
mt_ode_data = {}
rdmeTs = None
odeTs = None

# Process WT files
for traj_file in tqdm(wt_files, desc="Processing WT files", unit="file"):
    logging.info(f"Processing WT file: {traj_file}")
    traj, odeTraj, _ = get_traj(wt_traj_dir, traj_file, traj_suff)
    curr_rdmeTs, rdmeYs, curr_odeTs, odeYs, _, _ = get_data_for_plot(traj, odeTraj, region_traj=None, sparse_factor=1)
    # print("curr_rdmeTs", curr_rdmeTs)
    if rdmeTs is None:
        rdmeTs = curr_rdmeTs
        odeTs = curr_odeTs

    for species, data in rdmeYs.items():
        if species not in wt_species_data:
            wt_species_data[species] = []
        wt_species_data[species].append(data)

    for species, data in odeYs.items():
        if species not in wt_ode_data:
            wt_ode_data[species] = []
        wt_ode_data[species].append(data)
# Calculate and save WT statistics
wt_results = []
for species, trajectories in wt_species_data.items():
    # Truncate each trajectory to first 3601 frames
    truncated = [traj[:3601] for traj in trajectories]
    trajectories_array = np.array(truncated)
    avg = np.mean(trajectories_array, axis=0)
    std = np.std(trajectories_array, axis=0)
    
    wt_results.append({
        'Species': f"RDME_{species}",
        'Time': ','.join(map(str, rdmeTs[:3601])),
        'Average': ','.join(map(str, avg)),
        'Std': ','.join(map(str, std))
    })

# Similar for ODE data
for species, trajectories in wt_ode_data.items():
    truncated = [traj[:3601] for traj in trajectories]
    trajectories_array = np.array(truncated)
    avg = np.mean(trajectories_array, axis=0)
    std = np.std(trajectories_array, axis=0)
    
    wt_results.append({
        'Species': f"ODE_{species}",
        'Time': ','.join(map(str, odeTs[:3601])),
        'Average': ','.join(map(str, avg)),
        'Std': ','.join(map(str, std))
    })

# Process MT files
rdmeTs = None
odeTs = None

for traj_file in tqdm(mt_files, desc="Processing MT files", unit="file"):
    logging.info(f"Processing MT file: {traj_file}")
    traj, odeTraj, _ = get_traj(mt_traj_dir, traj_file, traj_suff)
    curr_rdmeTs, rdmeYs, curr_odeTs, odeYs, _, _ = get_data_for_plot(traj, odeTraj, region_traj=None, sparse_factor=1)
    if rdmeTs is None:
        rdmeTs = curr_rdmeTs
        odeTs = curr_odeTs
        
    for species, data in rdmeYs.items():
        if species not in mt_species_data:
            mt_species_data[species] = []
        mt_species_data[species].append(data)

    for species, data in odeYs.items():
        if species not in mt_ode_data:
            mt_ode_data[species] = []
        mt_ode_data[species].append(data)

# print("rdmeTs", rdmeTs)


# Calculate and save MT statistics
mt_results = []
for species, trajectories in mt_species_data.items():
    # Truncate each trajectory to first 3601 frames
    truncated = [traj[:3601] for traj in trajectories]
    trajectories_array = np.array(truncated)
    avg = np.mean(trajectories_array, axis=0)
    std = np.std(trajectories_array, axis=0)
    
    mt_results.append({
        'Species': f"RDME_{species}",
        'Time': ','.join(map(str, rdmeTs[:3601])),
        'Average': ','.join(map(str, avg * 2)),
        'Std': ','.join(map(str, std * 2))
    })

# Similar for MT ODE data
for species, trajectories in mt_ode_data.items():
    truncated = [traj[:3601] for traj in trajectories]
    trajectories_array = np.array(truncated)
    avg = np.mean(trajectories_array, axis=0)
    std = np.std(trajectories_array, axis=0)
    
    mt_results.append({
        'Species': f"ODE_{species}",
        'Time': ','.join(map(str, odeTs[:3601])),
        'Average': ','.join(map(str, avg * 2)),
        'Std': ','.join(map(str, std * 2))
    })

# Save to CSV files
wt_df = pd.DataFrame(wt_results)
mt_df = pd.DataFrame(mt_results)

wt_csv_path = os.path.join(fig_dir, 'wt_species_statistics.csv')
mt_csv_path = os.path.join(fig_dir, 'mt_species_statistics.csv')

wt_df.to_csv(wt_csv_path, index=False)
mt_df.to_csv(mt_csv_path, index=False)

logging.info(f"WT statistics saved to: {wt_csv_path}")
logging.info(f"MT statistics saved to: {mt_csv_path}")
# Out:
# Processing WT files:   0%|          | 0/3 [00:00<?, ?file/s]2025-05-12 18:43:39,598 - INFO - Processing WT file: yeast1.12.4mt_multi_20241030_2_t420.0minGAE5.55mMramsey_wt_gpu4.lm
# Processing WT files:  33%|███▎      | 1/3 [00:02<00:04,  2.04s/file]2025-05-12 18:43:41,642 - INFO - Processing WT file: yeast1.12.4mt_multi_20241030_3_t420.0minGAE5.55mMramsey_wt_gpu4.lm
# Processing WT files:  67%|██████▋   | 2/3 [00:04<00:02,  2.07s/file]2025-05-12 18:43:43,736 - INFO - Processing WT file: yeast1.12.4mt_multi_20241114_1_t420.0minGAE5.55mMramsey_wt_gpu4.lm
# Processing WT files: 100%|██████████| 3/3 [00:06<00:00,  2.08s/file]
# Processing MT files:   0%|          | 0/5 [00:00<?, ?file/s]2025-05-12 18:43:46,026 - INFO - Processing MT file: yeast1.14.3mt20250309_61_t120.0minGAE5.55mMwtRamsey_gpu4.lm
# Processing MT files:  20%|██        | 1/5 [00:01<00:07,  1.76s/file]2025-05-12 18:43:47,782 - INFO - Processing MT file: yeast1.14.3mt20250313_71_t120.0minGAE5.55mM2nd_run_gpu4.lm
# Processing MT files:  40%|████      | 2/5 [00:03<00:05,  1.74s/file]2025-05-12 18:43:49,507 - INFO - Processing MT file: yeast1.14.3mt20250309_41_t120.0minGAE5.55mMwtRamsey_gpu4.lm
# Processing MT files:  60%|██████    | 3/5 [00:05<00:03,  1.75s/file]2025-05-12 18:43:51,262 - INFO - Processing MT file: yeast1.14.3mt20250309_51_t120.0minGAE5.55mMwtRamsey_gpu4.lm
# Processing MT files:  80%|████████  | 4/5 [00:06<00:01,  1.75s/file]2025-05-12 18:43:53,022 - INFO - Processing MT file: yeast1.14.3mt20250309_31_t120.0minGAE5.55mMwtRamsey_gpu4.lm
# Processing MT files: 100%|██████████| 5/5 [00:08<00:00,  1.75s/file]
# 2025-05-12 18:43:55,077 - INFO - WT statistics saved to: /data2/2024_Yeast_GS/my_current_code/rdme_ode_results/20250512_MT_1hour/figures_comparison_WTMT/wt_species_statistics.csv
# 2025-05-12 18:43:55,078 - INFO - MT statistics saved to: /data2/2024_Yeast_GS/my_current_code/rdme_ode_results/20250512_MT_1hour/figures_comparison_WTMT/mt_species_statistics.csv

# %% [markdown]
# plot comparison graphs, this part can run separately

# %%
# Read the saved statistics
wt_df = pd.read_csv(os.path.join(fig_dir, 'wt_species_statistics.csv'))
mt_df = pd.read_csv(os.path.join(fig_dir, 'mt_species_statistics.csv'))

# Function to convert string of comma-separated values to numpy array
def str_to_array(s):
    return np.array([float(x) for x in s.split(',')])

# Debug: Print available species
logging.info("Available species in WT:")
logging.info (wt_df['Species'].tolist())
logging.info("Available species in MT:")
logging.info(mt_df['Species'].tolist())

# Get unique species names directly from the CSV
unique_species = set(wt_df['Species'].unique()) | set(mt_df['Species'].unique())
logging.info(f"\nUnique species:  {unique_species}")

# Plot settings
plt.style.use('default')
plt.rcParams['figure.figsize'] = [10, 6]
plt.rcParams['figure.dpi'] = 600
plt.rcParams['font.size'] = 18  # Increase base font size
plt.rcParams['axes.titlesize'] = 28  # Increase title font size
plt.rcParams['axes.labelsize'] = 18  # Increase axis label font size
plt.rcParams['xtick.labelsize'] = 18  # Increase tick label font size
plt.rcParams['ytick.labelsize'] = 18  # Increase tick label font size
plt.rcParams['legend.fontsize'] = 18  # Increase legend font size


# Create plots for each species
for species_name in unique_species:
    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Safely get data
    wt_species_data = wt_df[wt_df['Species'] == species_name]
    mt_species_data = mt_df[mt_df['Species'] == species_name]
    
    if len(wt_species_data) == 0 or len(mt_species_data) == 0:
        logging.info(f"Skipping {species_name} - data not found")
        continue
        
    wt_data = wt_species_data.iloc[0]
    mt_data = mt_species_data.iloc[0]
    
    # Get time arrays and data for both datasets
    wt_time = str_to_array(wt_data['Time'])
    mt_time = str_to_array(mt_data['Time'])
    wt_avg = str_to_array(wt_data['Average'])
    wt_std = str_to_array(wt_data['Std'])
    mt_avg = str_to_array(mt_data['Average'])
    mt_std = str_to_array(mt_data['Std'])
    
    # Find common time points
    common_times = np.intersect1d(wt_time, mt_time)
    logging.info(f"Number of common time points for {species_name}: {len(common_times)}")
    
    # Get indices for common time points in each dataset
    wt_indices = np.isin(wt_time, common_times)
    mt_indices = np.isin(mt_time, common_times)
    
    # Filter data to include only common time points
    time = common_times
    wt_avg = wt_avg[wt_indices]
    wt_std = wt_std[wt_indices]
    mt_avg = mt_avg[mt_indices]
    mt_std = mt_std[mt_indices]
    
    # Convert time from minutes to hours
    time_hours = [t for t in time if t <= 60]
    
    # Extract only the part after underscore for display in legend
    display_name = species_name.split('_', 1)[1] if '_' in species_name else species_name
    
    # Plot WT with solid line
    ax.plot(time_hours, wt_avg, label=f'MT {display_name}', 
            linestyle='-', linewidth=2)
    ax.fill_between(time_hours, wt_avg - wt_std, wt_avg + wt_std, 
                    alpha=0.2)
    
    # Plot MT with dashed line
    ax.plot(time_hours, mt_avg , label=f'WT {display_name}', 
            linestyle='--', linewidth=2)
    ax.fill_between(time_hours, mt_avg - mt_std, mt_avg + mt_std, 
                    alpha=0.2)
    
    # Customize plot
    ax.set_xlabel('Time (Minutes)')
    ax.set_ylabel('Counts')
    # ax.set_title(f'{display_name} Comparison in RDME-ODE')
    
    # # Set integer hour ticks
    # max_hour = int(np.ceil(max(time_hours)))
    # ax.set_xticks(range(0, max_hour + 1))
    
    ax.legend(framealpha=0.3)
    ax.grid(False)  # Remove grid to match the other style
    ax.set_ylim(bottom=0)
    # Save figure
    # plt.tight_layout()
    fig_path = os.path.join(fig_dir, f'{species_name}_comparison in RDME-ODE.png')
    plt.savefig(fig_path, dpi=600, bbox_inches='tight')
    logging.info(f"Saved plot for {species_name}")
    plt.close()
## logging info cl
logging.info(f"\nPlots saved in: {fig_dir}")
logging.getLogger().handlers[0].flush()
# Out:
# 2025-05-12 18:43:55,146 - INFO - Available species in WT:
# 2025-05-12 18:43:55,147 - INFO - ['RDME_DGrep', 'RDME_DGrep_G4d', 'RDME_DGrep_G4d_G80d', 'RDME_Rrep', 'RDME_Grep', 'RDME_DG1', 'RDME_DG1_G4d', 'RDME_DG1_G4d_G80d', 'RDME_R1', 'RDME_G1', 'RDME_DG2', 'RDME_DG2_G4d', 'RDME_DG2_G4d_G80d', 'RDME_R2', 'RDME_G2', 'RDME_DG3', 'RDME_DG3_G4d', 'RDME_DG3_G4d_G80d', 'RDME_R3', 'RDME_G3', 'RDME_G3i', 'RDME_DG4', 'RDME_R4', 'RDME_G4', 'RDME_G4d', 'RDME_DG80', 'RDME_DG80_G4d', 'RDME_DG80_G4d_G80d', 'RDME_R80', 'RDME_G80', 'RDME_G80d', 'RDME_G80d_G3i', 'RDME_ribosome', 'RDME_ribosomeR1', 'RDME_ribosomeR2', 'RDME_ribosomeR3', 'RDME_ribosomeR4', 'RDME_ribosomeR80', 'RDME_ribosomeGrep', 'ODE_GAI', 'ODE_G1', 'ODE_G1GAI', 'ODE_G2GAI', 'ODE_G2GAE', 'ODE_G2']
# 2025-05-12 18:43:55,147 - INFO - Available species in MT:
# 2025-05-12 18:43:55,148 - INFO - ['RDME_DGrep', 'RDME_DGrep_G4d', 'RDME_DGrep_G4d_G80d', 'RDME_Rrep', 'RDME_Grep', 'RDME_DG1', 'RDME_DG1_G4d', 'RDME_DG1_G4d_G80d', 'RDME_R1', 'RDME_G1', 'RDME_DG2', 'RDME_DG2_G4d', 'RDME_DG2_G4d_G80d', 'RDME_R2', 'RDME_G2', 'RDME_DG3', 'RDME_DG3_G4d', 'RDME_DG3_G4d_G80d', 'RDME_R3', 'RDME_G3', 'RDME_G3i', 'RDME_DG4', 'RDME_R4', 'RDME_G4', 'RDME_G4d', 'RDME_DG80', 'RDME_DG80_G4d', 'RDME_DG80_G4d_G80d', 'RDME_R80', 'RDME_G80', 'RDME_G80d', 'RDME_G80d_G3i', 'RDME_ribosome', 'RDME_ribosomeR1', 'RDME_ribosomeR2', 'RDME_ribosomeR3', 'RDME_ribosomeR4', 'RDME_ribosomeR80', 'RDME_ribosomeGrep', 'ODE_GAI', 'ODE_G1', 'ODE_G1GAI', 'ODE_G2GAI', 'ODE_G2GAE', 'ODE_G2']
# 2025-05-12 18:43:55,149 - INFO -
# Unique species:  {'RDME_G4d', 'RDME_DG4', 'ODE_G1GAI', 'RDME_Rrep', 'RDME_ribosomeR4', 'RDME_DG80_G4d_G80d', 'RDME_DG3', 'ODE_GAI', 'ODE_G2GAE', 'RDME_G80d', 'RDME_DG2', 'RDME_R4', 'RDME_DG2_G4d', 'RDME_ribosome', 'RDME_G3', 'RDME_DG1_G4d_G80d', 'RDME_DG80', 'RDME_G2', 'RDME_DG3_G4d', 'RDME_DG3_G4d_G80d', 'RDME_ribosomeR80', 'RDME_R3', 'RDME_DG1_G4d', 'RDME_G80', 'RDME_DGrep_G4d_G80d', 'RDME_DGrep_G4d', 'ODE_G2', 'RDME_DGrep', 'RDME_ribosomeR2', 'RDME_ribosomeR3', 'RDME_G4', 'ODE_G2GAI', 'RDME_DG1', 'RDME_ribosomeR1', 'RDME_R80', 'RDME_R2', 'RDME_ribosomeGrep', 'RDME_DG80_G4d', 'RDME_G1', 'RDME_G3i', 'RDME_Grep', 'ODE_G1', 'RDME_R1', 'RDME_DG2_G4d_G80d', 'RDME_G80d_G3i'}
# 2025-05-12 18:43:55,194 - INFO - Number of common time points for RDME_G4d: 1801
# 2025-05-12 18:43:56,093 - INFO - Saved plot for RDME_G4d
# 2025-05-12 18:43:56,110 - INFO - Number of common time points for RDME_DG4: 1801
# 2025-05-12 18:43:56,904 - INFO - Saved plot for RDME_DG4
# 2025-05-12 18:43:56,924 - INFO - Number of common time points for ODE_G1GAI: 1801
# 2025-05-12 18:43:57,922 - INFO - Saved plot for ODE_G1GAI
# 2025-05-12 18:43:57,940 - INFO - Number of common time points for RDME_Rrep: 1801
# 2025-05-12 18:43:59,114 - INFO - Saved plot for RDME_Rrep
# 2025-05-12 18:43:59,131 - INFO - Number of common time points for RDME_ribosomeR4: 1801
# 2025-05-12 18:44:00,275 - INFO - Saved plot for RDME_ribosomeR4
# 2025-05-12 18:44:00,292 - INFO - Number of common time points for RDME_DG80_G4d_G80d: 1801
# 2025-05-12 18:44:01,205 - INFO - Saved plot for RDME_DG80_G4d_G80d
# 2025-05-12 18:44:01,222 - INFO - Number of common time points for RDME_DG3: 1801
# 2025-05-12 18:44:02,045 - INFO - Saved plot for RDME_DG3
# 2025-05-12 18:44:02,064 - INFO - Number of common time points for ODE_GAI: 1801
# 2025-05-12 18:44:03,017 - INFO - Saved plot for ODE_GAI
# 2025-05-12 18:44:03,036 - INFO - Number of common time points for ODE_G2GAE: 1801
# 2025-05-12 18:44:04,053 - INFO - Saved plot for ODE_G2GAE
# 2025-05-12 18:44:04,201 - INFO - Number of common time points for RDME_G80d: 1801
# 2025-05-12 18:44:05,114 - INFO - Saved plot for RDME_G80d
# 2025-05-12 18:44:05,131 - INFO - Number of common time points for RDME_DG2: 1801
# 2025-05-12 18:44:05,989 - INFO - Saved plot for RDME_DG2
# 2025-05-12 18:44:06,005 - INFO - Number of common time points for RDME_R4: 1801
# 2025-05-12 18:44:06,965 - INFO - Saved plot for RDME_R4
# 2025-05-12 18:44:06,982 - INFO - Number of common time points for RDME_DG2_G4d: 1801
# 2025-05-12 18:44:08,019 - INFO - Saved plot for RDME_DG2_G4d
# 2025-05-12 18:44:08,038 - INFO - Number of common time points for RDME_ribosome: 1801
# 2025-05-12 18:44:08,861 - INFO - Saved plot for RDME_ribosome
# 2025-05-12 18:44:08,879 - INFO - Number of common time points for RDME_G3: 1801
# 2025-05-12 18:44:09,886 - INFO - Saved plot for RDME_G3
# 2025-05-12 18:44:09,904 - INFO - Number of common time points for RDME_DG1_G4d_G80d: 1801
# 2025-05-12 18:44:10,906 - INFO - Saved plot for RDME_DG1_G4d_G80d
# 2025-05-12 18:44:10,923 - INFO - Number of common time points for RDME_DG80: 1801
# 2025-05-12 18:44:11,763 - INFO - Saved plot for RDME_DG80
# 2025-05-12 18:44:11,781 - INFO - Number of common time points for RDME_G2: 1801
# 2025-05-12 18:44:12,824 - INFO - Saved plot for RDME_G2
# 2025-05-12 18:44:12,841 - INFO - Number of common time points for RDME_DG3_G4d: 1801
# 2025-05-12 18:44:13,742 - INFO - Saved plot for RDME_DG3_G4d
# 2025-05-12 18:44:13,759 - INFO - Number of common time points for RDME_DG3_G4d_G80d: 1801
# 2025-05-12 18:44:14,658 - INFO - Saved plot for RDME_DG3_G4d_G80d
# 2025-05-12 18:44:14,677 - INFO - Number of common time points for RDME_ribosomeR80: 1801
# 2025-05-12 18:44:15,787 - INFO - Saved plot for RDME_ribosomeR80
# 2025-05-12 18:44:15,806 - INFO - Number of common time points for RDME_R3: 1801
# 2025-05-12 18:44:17,129 - INFO - Saved plot for RDME_R3
# 2025-05-12 18:44:17,146 - INFO - Number of common time points for RDME_DG1_G4d: 1801
# 2025-05-12 18:44:18,140 - INFO - Saved plot for RDME_DG1_G4d
# 2025-05-12 18:44:18,159 - INFO - Number of common time points for RDME_G80: 1801
# 2025-05-12 18:44:19,324 - INFO - Saved plot for RDME_G80
# 2025-05-12 18:44:19,341 - INFO - Number of common time points for RDME_DGrep_G4d_G80d: 1801
# 2025-05-12 18:44:20,350 - INFO - Saved plot for RDME_DGrep_G4d_G80d
# 2025-05-12 18:44:20,438 - INFO - Number of common time points for RDME_DGrep_G4d: 1801
# 2025-05-12 18:44:21,450 - INFO - Saved plot for RDME_DGrep_G4d
# 2025-05-12 18:44:21,470 - INFO - Number of common time points for ODE_G2: 1801
# 2025-05-12 18:44:22,335 - INFO - Saved plot for ODE_G2
# 2025-05-12 18:44:22,352 - INFO - Number of common time points for RDME_DGrep: 1801
# 2025-05-12 18:44:23,116 - INFO - Saved plot for RDME_DGrep
# 2025-05-12 18:44:23,135 - INFO - Number of common time points for RDME_ribosomeR2: 1801
# 2025-05-12 18:44:24,246 - INFO - Saved plot for RDME_ribosomeR2
# 2025-05-12 18:44:24,265 - INFO - Number of common time points for RDME_ribosomeR3: 1801
# 2025-05-12 18:44:25,601 - INFO - Saved plot for RDME_ribosomeR3
# 2025-05-12 18:44:25,621 - INFO - Number of common time points for RDME_G4: 1801
# 2025-05-12 18:44:26,708 - INFO - Saved plot for RDME_G4
# 2025-05-12 18:44:26,727 - INFO - Number of common time points for ODE_G2GAI: 1801
# 2025-05-12 18:44:27,781 - INFO - Saved plot for ODE_G2GAI
# 2025-05-12 18:44:27,798 - INFO - Number of common time points for RDME_DG1: 1801
# 2025-05-12 18:44:28,598 - INFO - Saved plot for RDME_DG1
# 2025-05-12 18:44:28,616 - INFO - Number of common time points for RDME_ribosomeR1: 1801
# 2025-05-12 18:44:29,672 - INFO - Saved plot for RDME_ribosomeR1
# 2025-05-12 18:44:29,690 - INFO - Number of common time points for RDME_R80: 1801
# 2025-05-12 18:44:30,869 - INFO - Saved plot for RDME_R80
# 2025-05-12 18:44:30,888 - INFO - Number of common time points for RDME_R2: 1801
# 2025-05-12 18:44:32,153 - INFO - Saved plot for RDME_R2
# 2025-05-12 18:44:32,172 - INFO - Number of common time points for RDME_ribosomeGrep: 1801
# 2025-05-12 18:44:33,257 - INFO - Saved plot for RDME_ribosomeGrep
# 2025-05-12 18:44:33,273 - INFO - Number of common time points for RDME_DG80_G4d: 1801
# 2025-05-12 18:44:34,196 - INFO - Saved plot for RDME_DG80_G4d
# 2025-05-12 18:44:34,214 - INFO - Number of common time points for RDME_G1: 1801
# 2025-05-12 18:44:35,192 - INFO - Saved plot for RDME_G1
# 2025-05-12 18:44:35,210 - INFO - Number of common time points for RDME_G3i: 1801
# 2025-05-12 18:44:36,226 - INFO - Saved plot for RDME_G3i
# 2025-05-12 18:44:36,244 - INFO - Number of common time points for RDME_Grep: 1801
# 2025-05-12 18:44:37,248 - INFO - Saved plot for RDME_Grep
# 2025-05-12 18:44:37,267 - INFO - Number of common time points for ODE_G1: 1801
# 2025-05-12 18:44:38,186 - INFO - Saved plot for ODE_G1
# 2025-05-12 18:44:38,204 - INFO - Number of common time points for RDME_R1: 1801
# 2025-05-12 18:44:39,288 - INFO - Saved plot for RDME_R1
# 2025-05-12 18:44:39,305 - INFO - Number of common time points for RDME_DG2_G4d_G80d: 1801
# 2025-05-12 18:44:40,314 - INFO - Saved plot for RDME_DG2_G4d_G80d
# 2025-05-12 18:44:40,333 - INFO - Number of common time points for RDME_G80d_G3i: 1801
# 2025-05-12 18:44:41,301 - INFO - Saved plot for RDME_G80d_G3i
# 2025-05-12 18:44:41,302 - INFO -
# Plots saved in: /data2/2024_Yeast_GS/my_current_code/rdme_ode_results/20250512_MT_1hour/figures_comparison_WTMT/

# %% [markdown]
# normalized Grep

# %%
# Add a function to plot normalized Grep comparison
def plot_normalized_grep(wt_df, mt_df, save=True):
    """Plot comparison for Grep (reporter) with normalized y-axis (0-1)"""
    
    species_name = 'RDME_Grep'  # The species name for Grep in the dataset
    display_name = 'Grep'
    
    # Safely get data
    wt_species_data = wt_df[wt_df['Species'] == species_name]
    mt_species_data = mt_df[mt_df['Species'] == species_name]
    
    if len(wt_species_data) == 0 or len(mt_species_data) == 0:
        logging.info(f"Skipping {species_name} - data not found")
        return None
        
    wt_data = wt_species_data.iloc[0]
    mt_data = mt_species_data.iloc[0]
    
    # Get time arrays and data for both datasets
    wt_time = str_to_array(wt_data['Time'])
    mt_time = str_to_array(mt_data['Time'])
    wt_avg = str_to_array(wt_data['Average'])
    wt_std = str_to_array(wt_data['Std'])
    mt_avg = str_to_array(mt_data['Average'])
    mt_std = str_to_array(mt_data['Std'])
    
    # Find common time points
    common_times = np.intersect1d(wt_time, mt_time)
    logging.info(f"Number of common time points for {species_name}: {len(common_times)}")
    
    # Get indices for common time points in each dataset
    wt_indices = np.isin(wt_time, common_times)
    mt_indices = np.isin(mt_time, common_times)
    
    # Filter data to include only common time points
    time = common_times
    wt_avg = wt_avg[wt_indices]
    wt_std = wt_std[wt_indices]
    mt_avg = mt_avg[mt_indices]
    mt_std = mt_std[mt_indices]
    
    # Convert time from minutes to hours
    # time_hours = time / 60.0
    time_hours = time
    # Find global max value across both datasets including standard deviations
    max_with_std_wt = np.max(wt_avg + wt_std)
    max_with_std_mt = np.max(mt_avg + mt_std)
    global_max = max(max_with_std_wt, max_with_std_mt)
    
    # Normalize both datasets using the global max
    norm_wt_avg = wt_avg / global_max
    norm_wt_std = wt_std / global_max
    
    norm_mt_avg = mt_avg / global_max
    norm_mt_std = mt_std / global_max
    
    # Create the plot
    fig, ax = plt.subplots(figsize=(10, 6))
    
    # Plot WT with solid line
    ax.plot(time_hours, norm_wt_avg, label=f'WT {display_name}', 
            linestyle='-', linewidth=2)
    ax.fill_between(time_hours, norm_wt_avg - norm_wt_std, norm_wt_avg + norm_wt_std, 
                    alpha=0.2)
    
    # Plot MT with dashed line
    ax.plot(time_hours, norm_mt_avg, label=f'MT {display_name}', 
            linestyle='--', linewidth=2)
    ax.fill_between(time_hours, norm_mt_avg - norm_mt_std, norm_mt_avg + norm_mt_std, 
                    alpha=0.2)
    
    # Customize plot
    ax.set_xlabel('Time (minutes)')
    ax.set_ylabel('Normalized Counts')
    
    # Set integer hour ticks
    max_hour = int(np.ceil(max(time_hours)))
    ax.set_xticks(range(0, max_hour + 1))
    
    # Set y-axis limits to 0-1
    ax.set_ylim(0, 1.1)  # Slightly above 1 to show the full range
    
    ax.legend(framealpha=0.3, loc='upper left')
    ax.grid(False)
    
    # Save figure
    if save:
        # plt.tight_layout()
        fig_path = os.path.join(fig_dir, f'{species_name}_normalized_comparison in RDME-ODE.png')
        plt.savefig(fig_path, dpi=600, bbox_inches='tight')
        logging.info(f"Saved normalized plot for {display_name}")
        plt.close()
    else:
        # plt.tight_layout()
        plt.show()
        
    return fig

# Add this after your existing plotting loop
# Plot normalized version for Grep (reporter)
plot_normalized_grep(wt_df, mt_df)
# Out:
# 2025-05-12 18:44:41,774 - INFO - Number of common time points for RDME_Grep: 1801
# 2025-05-12 18:44:43,064 - INFO - Saved normalized plot for Grep
