# %%
lm_file =  "/data2/2024_Yeast_GS/my_current_code/rdme_ode/simulation_results_id_99/yeast1.16_combined_20250912_99_t0.02min_GAE11.1mM_ER_CHROMOtest_mRNA_tracking_gpu2.lm"

from jLM.RDME import File as RDMEFile

rdme_file = RDMEFile(lm_file)
# Out:
# <style>
# table.fullWidth {
#     width: 100%;
# }
#
# table.jLMtbl {
#     border: 1px solid #000;
# }
#
# .jLMtbl td, .jLMtbl tr, .jLMtbl th, .diffTbl table, .diffTbl td, .diffTbl tr {
#     border: 0px;
# }
#
# .jLMtbl caption, .diffTbl caption {
#     font-size: 1.5em;
#     font-weight: bold;
#     color: #555;
#     text-align: left;
#     padding: 15px 10px 8px 10px;
# }
#
# .jLMtbl td, .jLMtbl th {
#     padding-left: 10px;
#     padding-right: 10px;
# }
#
# .jLMtbl tr:nth-child(even) { background: #ddd;  }
# .jLMtbl tr:nth-child(odd) { background: #f8f8f8;  }
#
# table.diffTbl {
#     border: 0px;
# }
#
# td.noWrap {
#     white-space:nowrap;
# }
#
# .diffTbl span.rot {
#     -webkit-transform: rotate(-90deg);
#     transform: rotate(-90deg);
#     display: inline-block;
#     white-space: nowrap;
# }
#
# .diffTbl td[rowspan], .diffTbl td[colspan] {
#     background: #fff;
#     font-weight: bold;
# }
#
# .diffTbl td[rowspan] {
#     width: 0.01em;
#     padding: 0em 0.2em;
# ...

# %%
rdme_file.showSpecies("R2")
# Out:
# <div class="jLMbigSps">$\mathrm{R2}$</div>
# <table class='jLMtbl'>
#     <tr>
#         <th scope='row'>Index</th>
#         <td class='jLMparam'><tt>14</tt></td>
#     </tr>
#     <tr>
#         <th scope='row'>Label</th>
#         <td class='jLMparam'><tt>R2</tt></td>
#     </tr>
#     <tr>
#         <th scope='row'>Total counts</th>
#         <td class='jLMparam jLMnum'>0</td>
#     </tr>
#     <tr>
#         <th scope='row'>Total reactions</th>
#         <td class='jLMparam jLMnum'>4</td>
#     </tr>
# </table>
#
#
#
# <table class="jLMtbl">
#     <caption>Reactions</caption>
#     <tr>
#         <th scope='col'>Index</th>
#         <th scope='col'>Reaction</th>
#         <th scope='col'>Rate</th>
#         <th scope='col'>Regions</th>
#     </tr>
#     <tr class='jLMtbl'>
#         <td class="objIndex"> 32 </td>
#         <td class="rxnCol"> $\mathrm{DG2\_G4d}\overset{k_{\mathrm{alpha2}}}{\longrightarrow}\mathrm{DG2\_G4d} + \mathrm{R2}$ </td>
# ...
