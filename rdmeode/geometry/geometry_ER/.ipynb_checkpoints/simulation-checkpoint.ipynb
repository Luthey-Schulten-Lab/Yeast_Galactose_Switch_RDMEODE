# %%
import ipywidgets as ipw
import IPython.display as ipd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from venv import *

# %%
import jLM
from jLM.RegionBuilder import RegionBuilder
from jLM.RDME import Sim as RDMESim
from jLM.RDME import File as RDMEFile
from jLM.JupyterDisplay import boundaryPath
from ReadVolBin import VolData
# Out:
# <style>
# table.fullWidth {
#     width: 100%;
# }
#
# table.jLMtbl {
#     border: 1px solid #000;
# }
#
# .jLMtbl td, .jLMtbl tr, .jLMtbl th, .diffTbl table, .diffTbl td, .diffTbl tr {
#     border: none;
# }
#
# .jLMtbl caption, .diffTbl caption {
#     font-size: 1.5em;
#     font-weight: bold;
#     color: #555;
#     text-align: left;
#     padding: 15px 10px 8px 10px;
# }
#
# .jLMtbl td, .jLMtbl th {
#     padding-left: 10px;
#     padding-right: 10px;
# }
#
# .jLMtbl tr:nth-child(even) { background: #ddd;  }
# .jLMtbl tr:nth-child(odd) { background: #f8f8f8;  }
#
# table.diffTbl {
#     width: 100%;
#     border: none;
# }
#
# .diffTbl span.rot {
#     -webkit-transform: rotate(-90deg);
#     transform: rotate(-90deg);
#     display: inline-block;
#     white-space: nowrap;
# }
#
# .diffTbl td[rowspan], .diffTbl td[colspan] {
#     background: #fff;
#     font-weight: bold;
# }
#
# .diffTbl td[rowspan] {
#     width: 0.01em;
#     padding: 0;
# }
#
#
# .diffTbl td {
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     vertical-align: middle;
#     background-color: hsla(0,0%,90%,1);
#     color: #000;
# }
#
#
# .diffTbl td.rhdr {
#     text-align: right;
#     background: #555;
#     color: #fff;
# }
#
# .diffTbl td.units {
#     background: #fff;
#     color: #000;
# }
#
# .diffTbl td.chdr {
#     padding-left: 2px;
#     padding-right: 2px;
#     text-align: center;
#     background: #555;
#     color: #fff;
# }
#
# .diffTbl td.zero {
#     background-color: hsla(180,100%,90%,1);
# }
#
# .diffTbl td.inf {
#     background-color: hsla(0,100%,90%,1);
# }
#
# .diffTbl td.undef {
#     background-color: #f00;
#     color: #fff;
# }
#
#
# .jLMtbl th {
#     border: none;
#     background: #555;
#     color: #fff;
# }
#
# .jLMtbl th[scope=col] {
#     height: 40px;
#     text-align: center;
#     vertical-align: middle;
# }
#
# .jLMtbl th[scope=row] {
#     text-align: left;
# }
#
# td.jLMparam{
#     width: 250px;
#     text-align: right;
#     padding-right: 15px;
# }
#
#
# td.objIndex {
#     width: 15px;
#     text-align:center;
#     vertical-align:middle;
# }
#
#
# div.jLMflex {
#     width: 100%;
#     display: flex;
#     margin:0;
# }
#
# div.regRight, div.trajRight {
#     flex-grow: 1;
# }
#
# div.trajRight {
#     padding-top: 20px;
# }
#
# div.regLeft {
#     width:200px;
# }
#
# div.trajLeft {
#     width:400px;
# }
#
# div.jLMx3Dkey {
#     position: absolute;
#     background-color: white;
#     top: 2px;
#     right: 2px;
#     width: 225px;
#     border: 1px solid #000;
#     padding: 0px;
# }
#
# ul.reg, button.reg {
#     list-style-type: none;
#     width: 100%;
# }
#
# img.smallreg {
#     border:1px solid #000;
#     float: left;
#     image-rendering: -moz-crisp-edges;
#     image-rendering: -o-crisp-edges;
#     image-rendering: -webkit-optimize-contrast;
#     -ms-interpolation-mode: nearest-neighbor;
#     image-rendering: pixelated;
# }
#
# X3D.jLM {
#     width: 980px;
#     height: 600px;
#     border: none;
# }
#
# span.jLMparticleKey {
#     position: relative;
#     top: 3px;
#     font-size: 1.5em;
# }
#
# div.jLMbigSps {
#     font-family: serif;
#     background: #fff;
#     color: #000;
#     display: table-cell;
#     vertical-align: middle;
#     text-align: center;
#     height: 70px;
#     font-size: 3.2em;
#     padding: 40px 10px 10px 10px;
#     border: none;
# }
#
# input[type=range][orient=vertical].stackSlider {
#     writing-mode: bt-lr; /* IE */
#     display: block;
#     margin: auto;
#     -webkit-appearance: slider-vertical; /* WebKit */
#     width: 8px;
#     height: 250px;
#     padding: 15px;
# }
#
# span.jLMregion {
#     padding: 1px 4px;
#     margin: 2px;
#     display: inline-block;
#     font-family: sans-serif;
#     border: 1px solid black;
# }
#
# span.jLMnum, td.jLMnum {
#     font-family: serif;
#     font-size: 1.2em;
# }
#
# </style>

# %%
import numpy as np
import pickle
import itertools
import scipy.ndimage as ndi
import scipy.linalg as la
import skimage.measure as skme

# %%
siteData = pickle.load(open(simFile("siteLattice.p"),"rb"))
shape = siteData['lattice'].shape

names = sorted(siteData['names'].keys(), key=lambda x: siteData['names'][x])

sim = RDMESim("helaExpression", simFile("helaExpression-absBC.lm"), shape, 8e-9, names[0], dt=2.665e-6)

for name in names:
    sim.region(name)
    
sim.siteLattice[...] = siteData['lattice']

# %%
extracellular = sim.region("extracellular")
nuclearEnv    = sim.region("nuclearEnvelope")
microtubules  = sim.region("microtubules")
actin         = sim.region("actin")
npc           = sim.region("npc")
er            = sim.region("er")
ssu           = sim.region("ssu")
lsu           = sim.region("lsu")
cytoplasm     = sim.region("cytoplasm")
nucleoplasm   = sim.region("nucleoplasm")
boundary      = sim.region("abBoundary")

# %%
mRNAsps = []
mRNAwaitSps = []
mRNAtxSps = []
repressorSps = []
geneOnSps = []
geneOffSps = []

ngrp = 8192//(len(sim.regionList)**2*6)

for i in range(ngrp):
    mRNAsps.append( sim.species("mRNA{:02d}".format(i)))
    mRNAtxSps.append( sim.species("mRNAtx{:02d}".format(i)))
    mRNAwaitSps.append( sim.species("mRNAwait{:02d}".format(i)))
    repressorSps.append( sim.species("repressor{:02d}".format(i)))
    geneOnSps.append( sim.species("geneOn{:02d}".format(i)))
    geneOffSps.append( sim.species("geneOff{:02d}".format(i)))
    
allSps = list(zip( mRNAsps, mRNAtxSps, mRNAwaitSps, repressorSps, geneOnSps, geneOffSps))

# %%
B = RegionBuilder(sim)
exclusionRadius = 4
availablePositions = B.erode(sim.siteLattice == nucleoplasm.idx, exclusionRadius)
exclusion = B.emptyLatticeMask()
for geneOn in geneOnSps:
    genePos= np.argwhere(availablePositions)
    x,y,z = genePos[np.random.randint(genePos.shape[0]),:]
    geneOn.placeParticle(int(x),int(y),int(z), 1)
    exclusion[...] = 0
    exclusion[x,y,z] = True
    exclusion = B.dilate(exclusion, se=B.sphereStructElem(exclusionRadius))
    availablePositions = availablePositions & ~exclusion

# %%
tsTime = 1 # one per second
tlTime = 1.0
tlWait = 0.05
reprOnTime = 0.1
reprOffTime = 1

# %%
k_ts      = sim.rateConst("ts", sim.siteNAV*np.log(2)/tsTime, 2)
k_tlInit  = sim.rateConst("tlInit", 0.01*np.log(2)/sim.timestep, 1)
k_tlTerm  = sim.rateConst("tlTerm", np.log(2)/tlTime, 1) 
k_mrnaRcv  = sim.rateConst("mrnaRcv", np.log(2)/tlWait, 1) 
k_repOn   = sim.rateConst("reprOn", sim.siteNAV*np.log(2)/reprOnTime, 2)
k_repOff  = sim.rateConst("reprOff", np.log(2)/reprOffTime, 1)
k_bcDcy   = sim.rateConst("bcDcy", 1/sim.timestep, 1)

# %%
for spSet in allSps:
    for sp in spSet:
        boundary.addReaction(sp, None, k_bcDcy)
    
for mRNA, mRNAtx, mRNAwait, repressor, geneOn, geneOff in allSps:
    nucleoplasm.addReaction(geneOn, (geneOn, mRNA), k_ts)
    for rib in [lsu,ssu]:
        rib.addReaction(mRNA, mRNAtx, k_tlInit)
        rib.addReaction(mRNAtx, (mRNAwait, repressor), k_tlTerm)
    nucleoplasm.addReaction((geneOn, repressor), geneOff, k_repOn)
    nucleoplasm.addReaction(geneOff, (geneOn,repressor), k_repOff)
    nucleoplasm.addReaction(mRNAwait, mRNA, k_mrnaRcv)
    cytoplasm.addReaction(mRNAwait, mRNA, k_mrnaRcv)

# %%
d_mRNA  = sim.diffusionConst("mRNA", 0.5e-12)
d_repr  = sim.diffusionConst("repr", 2e-12)
d_zero  = sim.diffusionZero()
d_fast  = sim.diffusionFast()

# %%
obstructionRegions = [ extracellular, nuclearEnv, microtubules, actin, npc, er ]
normalRegions = [nucleoplasm, cytoplasm, lsu, ssu]
plasm = [nucleoplasm, cytoplasm]
ribosome = [lsu,ssu]

sim.transitionRate(None, boundary, None, d_zero)

for r in obstructionRegions:
    r.transitionRateIn(d_zero)
    r.transitionRateOut(d_fast)
    
for r0, r1 in itertools.product(obstructionRegions, repeat=2):
    sim.transitionRate(None, r0, r1, d_zero)
        
for mRNA, mRNAtx, mRNAwait, repressor, geneOn, geneOff in allSps:
    
    for g in [geneOn, geneOff]:
        g.transitionRate(None,None,d_zero)
        g.transitionRate(None,nucleoplasm,d_fast)
        g.transitionRate(nucleoplasm,nucleoplasm,d_zero)
        g.transitionRate(boundary,nucleoplasm,d_zero)
    
    for r in normalRegions:
        for r1 in normalRegions:
            mRNA.transitionRate(r,r1, d_mRNA)
            repressor.transitionRate(r,r1, d_repr)
            mRNAtx.transitionRate(r,r1,d_zero)
            
        mRNAtx.transitionRate(r,boundary,d_zero)
        mRNAwait.transitionRate(r, boundary, d_mRNA)
        mRNA.transitionRate(r, boundary, d_mRNA)
        repressor.transitionRate(r, boundary, d_repr)
        
    for r0 in ribosome:
        for r1 in plasm:
            for sp in [repressor, mRNAwait]:
                sp.transitionRate(r0, r1, d_fast)
                sp.transitionRate(r1, r0, d_zero)
            
    for r0 in ribosome:
        for r1 in ribosome:
            mRNAwait.transitionRate(r0, r1, d_mRNA)
            
    for r0 in plasm:
        for r1 in plasm:
            mRNAwait.transitionRate(r0, r1, d_mRNA)

# %%
stepsPerWrite = 1000
sim.latticeWriteInterval =sim.timestep*stepsPerWrite
sim.speciesWriteInterval = sim.latticeWriteInterval
simWallRatio = sim.timestep/2.23e-3
sim.simulationTime = 10*60*simWallRatio
sim.finalize()

# %%
#sim.run()
# Out:
# 2016-12-15 12:26:46) Info: Using 32 processor(s) and 1 CUDA device(s) per process.
# 2016-12-15 12:26:46) Info: Assigning 1.00 processor(s) and 1.00 CUDA device(s) per replicate.
# 2016-12-15 12:26:46) Info: Data output thread running.
# 2016-12-15 12:26:46) Info: MPDRDME: Rng seed: top word 1983482310, bottom word 1
# 2016-12-15 12:26:46) Info: Running mpd rdme simulation with 66 species, 132 reactions, 11 site types for 7.170404e-01 s with tau 2.665000e-06. Writing species at 2.665000e-03 and lattice at 2.665000e-03 intervals
# 2016-12-15 12:27:46) Info: Wrote 27 data sets (1019217033 bytes) in the last 60.02 seconds (2.85 seconds writing). 0 datasets queued. Flushing.
# 2016-12-15 12:27:46) Info: Average walltime per timestep: 2.28 ms. Progress: 0.0702s/0.7170s ( 9.8% done / 9.2 minutes walltime remaining)
# 2016-12-15 12:28:46) Info: Average walltime per timestep: 2.29 ms. Progress: 0.1401s/0.7170s ( 19.5% done / 8.3 minutes walltime remaining)
# 2016-12-15 12:28:47) Info: Wrote 26 data sets (981468254 bytes) in the last 61.49 seconds (2.98 seconds writing). 0 datasets queued. Flushing.
# 2016-12-15 12:29:46) Info: Average walltime per timestep: 2.28 ms. Progress: 0.2103s/0.7170s ( 29.3% done / 7.2 minutes walltime remaining)
# 2016-12-15 12:29:49) Info: Wrote 27 data sets (1019217033 bytes) in the last 61.58 seconds (2.95 seconds writing). 0 datasets queued. Flushing.
# 2016-12-15 12:30:46) Info: Average walltime per timestep: 2.45 ms. Progress: 0.2757s/0.7170s ( 38.4% done / 6.7 minutes walltime remaining)
# 2016-12-15 12:30:51) Info: Wrote 25 data sets (943719475 bytes) in the last 62.08 seconds (3.01 seconds writing). 0 datasets queued. Flushing.
# 2016-12-15 12:31:46) Info: Average walltime per timestep: 2.45 ms. Progress: 0.3408s/0.7170s ( 47.5% done / 5.8 minutes walltime remaining)
# 2016-12-15 12:31:51) Info: Wrote 25 data sets (943719475 bytes) in the last 60.74 seconds (2.67 seconds writing). 0 datasets queued. Flushing.
# 2016-12-15 12:32:46) Info: Average walltime per timestep: 2.36 ms. Progress: 0.4086s/0.7170s ( 57% done / 4.5 minutes walltime remaining)
# 2016-12-15 12:32:52) Info: Wrote 26 data sets (981468254 bytes) in the last 60.61 seconds (3.17 seconds writing). 0 datasets queued. Flushing.
# 2016-12-15 12:33:46) Info: Average walltime per timestep: 2.40 ms. Progress: 0.4753s/0.7170s ( 66.3% done / 3.6 minutes walltime remaining)
# 2016-12-15 12:33:52) Info: Wrote 25 data sets (943719475 bytes) in the last 60.12 seconds (2.80 seconds writing). 0 datasets queued. Flushing.
# 2016-12-15 12:34:46) Info: Average walltime per timestep: 2.22 ms. Progress: 0.5473s/0.7170s ( 76.3% done / 2.4 minutes walltime remaining)
# 2016-12-15 12:34:52) Info: Wrote 28 data sets (1056965812 bytes) in the last 60.18 seconds (3.06 seconds writing). 0 datasets queued. Flushing.
# 2016-12-15 12:35:46) Info: Average walltime per timestep: 2.26 ms. Progress: 0.6182s/0.7170s ( 86.2% done / 1.4 minutes walltime remaining)
# 2016-12-15 12:35:53) Info: Wrote 26 data sets (981468254 bytes) in the last 60.55 seconds (3.05 seconds writing). 0 datasets queued. Flushing.
# 2016-12-15 12:36:46) Info: Average walltime per timestep: 2.28 ms. Progress: 0.6884s/0.7170s ( 96% done / 25 seconds walltime remaining)
# 2016-12-15 12:36:55) Info: Wrote 27 data sets (1019217033 bytes) in the last 61.72 seconds (3.14 seconds writing). 0 datasets queued. Flushing.
# 2016-12-15 12:37:13) Info: Data output thread finished.
# 2016-12-15 12:37:13) Info: Simulation file closed.
# <h2>helaExpression</h2>
#
# <div class="jLMflex">
#     <div class="regLeft">
#         <h3>Key</h3>
#         <ul class="reg">
#             <li><span class="jLMregion" style="color:#000000;background:#ffffff;">extracellular</span></li>
#             <li><span class="jLMregion" style="color:#000000;background:#51cccc;">nuclearEnvelope</span></li>
#             <li><span class="jLMregion" style="color:#ffffff;background:#337f7f;">microtubules</span></li>
#             <li><span class="jLMregion" style="color:#ffffff;background:#cc5151;">actin</span></li>
#             <li><span class="jLMregion" style="color:#ffffff;background:#7f3333;">npc</span></li>
#             <li><span class="jLMregion" style="color:#ffffff;background:#8e51cc;">er</span></li>
#             <li><span class="jLMregion" style="color:#ffffff;background:#59337f;">ssu</span></li>
#             <li><span class="jLMregion" style="color:#000000;background:#8ecc51;">lsu</span></li>
#             <li><span class="jLMregion" style="color:#ffffff;background:#597f33;">cytoplasm</span></li>
#             <li><span class="jLMregion" style="color:#ffffff;background:#5170cc;">nucleoplasm</span></li>
#             <li><span class="jLMregion" style="color:#ffffff;background:#33467f;">abBoundary</span></li>
#         </ul>
#     </div>
#     <div class="regRight">
#         <h3><i>xz</i>-plane; <i>y</i>-index=31</h3>
#         <img class="smallreg" width="384" height="384" src="data:image/png;base64,..." />
#     </div>
# </div>
# <table class='jLMtbl'>
#     <caption>Simulation</caption>
#     <tr>
#         <th> Time step </th>
#         <td class='jLMparam jLMnum'> 2.665 µs </td>
#     </tr>
#     <tr>
#         <th> Simulation time </th>
#         <td class='jLMparam jLMnum'> 0.717 s </td>
#     </tr>
#     <tr>
#         <th> Lattice write interval </th>
#         <td class='jLMparam jLMnum'> 2.665 × 10<sup>-3</sup> s </td>
#     </tr>
#     <tr>
#         <th scope='row'> Particle count write interval </th>
#         <td class='jLMparam jLMnum'> 2.665 × 10<sup>-3</sup> s </td>
#     </tr>
#     <tr>
#         <th scope='row'> Number of replicates </th>
#         <td class='jLMparam jLMnum'> 1 </td>
#     </tr>
# </table>
#
# <table class='jLMtbl'>
#     <caption>Trajectory data</caption>
#     <tr>
#         <th scope='col'> Replicate </th>
#         <th scope='col'> Simulated time </th>
#         <th scope='col'> Lattice times </th>
#         <th scope='col'> Count times </th>
#         <th scope='col'> Initial count </th>
#         <th scope='col'> Final count </th>
#     </tr>
#     <tr>
#         <td><tt>0000001</tt></td>
#         <td class='jLMnum'>0.717 s</td>
#         <td class="jLMnum">270</td>
#         <td class="jLMnum">270</td>
#         <td class="jLMnum">11</td>
#         <td class="jLMnum">31</td>
#     </tr>
#
#
#
# <table class='jLMtbl'>
#     <caption>Lattice</caption>
#     <tr>
#         <th scope='row'> Dimensions </th>
#         <td class='jLMparam jLMnum'>192 × 64 × 192</td>
#     </tr>
#     <tr>
#         <th scope='row'> Particles per site </th>
#         <td class='jLMparam jLMnum'>16</td>
#     </tr>
#     <tr>
#         <th scope='row'> Bytes per particle </th>
#         <td class='jLMparam jLMnum'>1</td>
#     </tr>
#     <tr>
#         <th scope='row'> Lattice spacing </th>
#         <td class='jLMparam jLMnum'> 8.000 nm</td>
#     </tr>
#     <tr>
#         <th scope='row'> Subvolume size </th>
#         <td class='jLMparam jLMnum'> 5.120 × 10<sup>-7</sup> fl </td>
#     </tr>
# </table>
#
#
# <table class='jLMtbl'>
#     <caption>Model summary</caption>
#     <tr>
#         <th scope='row'> Output file </th>
#         <td class='jLMparam'> <tt>/data/earnest3/research/festschwifty/sim/helaExpression-absBC.lm</tt> </td>
#     </tr>
#     <tr>
#         <th scope='row'> Number of species </th>
#         <td class='jLMparam jLMnum'>66</td>
#     </tr>
#     <tr>
#         <th scope='row'> Number of reactions </th>
#         <td class='jLMparam jLMnum'>132</td>
#     </tr>
#     <tr>
#         <th scope='row'> Number of region types </th>
#         <td class='jLMparam jLMnum'>11</td>
#     </tr>
#     <tr>
#         <th scope='row'> Number of rate constants </th>
#         <td class='jLMparam jLMnum'>7</td>
#     </tr>
#     <tr>
#         <th scope='row'> Number of diffusion constants </th>
#         <td class='jLMparam jLMnum'>4</td>
#     </tr>
#     <tr>
#         <th scope='row'> Number of placed particles</th>
#         <td class='jLMparam jLMnum'>0</td>
#     </tr>
# </table>
#
# <table class='jLMtbl'>
#     <caption>Region summary</caption>
#     <tr>
#         <th scope='col'> Region </th>
#         <th scope='col'> Subvolumes </th>
#         <th scope='col'> Volume </th>
#         <th scope='col'> Particles</th>
#         <th scope='col'> Concentration </th>
#         <th scope='col'> Occupancy </th>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#000000;background:#ffffff;">extracellular</span></td>
#         <td class='jLMnum'>1882743</td>
#         <td class='jLMnum'>0.964 fl</td>
#         <td class='jLMnum'>0</td>
#         <td class='jLMnum'>0.000 µM</td>
#         <td class='jLMnum'>$0.00\,\%$</td>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#000000;background:#51cccc;">nuclearEnvelope</span></td>
#         <td class='jLMnum'>20930</td>
#         <td class='jLMnum'>0.011 fl</td>
#         <td class='jLMnum'>0</td>
#         <td class='jLMnum'>0.000 µM</td>
#         <td class='jLMnum'>$0.00\,\%$</td>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#ffffff;background:#337f7f;">microtubules</span></td>
#         <td class='jLMnum'>10083</td>
#         <td class='jLMnum'>5.162 × 10<sup>-3</sup> fl</td>
#         <td class='jLMnum'>0</td>
#         <td class='jLMnum'>0.000 µM</td>
#         <td class='jLMnum'>$0.00\,\%$</td>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#ffffff;background:#cc5151;">actin</span></td>
#         <td class='jLMnum'>4815</td>
#         <td class='jLMnum'>2.465 × 10<sup>-3</sup> fl</td>
#         <td class='jLMnum'>0</td>
#         <td class='jLMnum'>0.000 µM</td>
#         <td class='jLMnum'>$0.00\,\%$</td>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#ffffff;background:#7f3333;">npc</span></td>
#         <td class='jLMnum'>4715</td>
#         <td class='jLMnum'>2.414 × 10<sup>-3</sup> fl</td>
#         <td class='jLMnum'>0</td>
#         <td class='jLMnum'>0.000 µM</td>
#         <td class='jLMnum'>$0.00\,\%$</td>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#ffffff;background:#8e51cc;">er</span></td>
#         <td class='jLMnum'>3488</td>
#         <td class='jLMnum'>1.786 × 10<sup>-3</sup> fl</td>
#         <td class='jLMnum'>0</td>
#         <td class='jLMnum'>0.000 µM</td>
#         <td class='jLMnum'>$0.00\,\%$</td>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#ffffff;background:#59337f;">ssu</span></td>
#         <td class='jLMnum'>3919</td>
#         <td class='jLMnum'>2.007 × 10<sup>-3</sup> fl</td>
#         <td class='jLMnum'>1</td>
#         <td class='jLMnum'>0.828 µM</td>
#         <td class='jLMnum'>$0.00\,\%$</td>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#000000;background:#8ecc51;">lsu</span></td>
#         <td class='jLMnum'>7909</td>
#         <td class='jLMnum'>4.049 × 10<sup>-3</sup> fl</td>
#         <td class='jLMnum'>0</td>
#         <td class='jLMnum'>0.000 µM</td>
#         <td class='jLMnum'>$0.00\,\%$</td>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#ffffff;background:#597f33;">cytoplasm</span></td>
#         <td class='jLMnum'>242390</td>
#         <td class='jLMnum'>0.124 fl</td>
#         <td class='jLMnum'>0</td>
#         <td class='jLMnum'>0.000 µM</td>
#         <td class='jLMnum'>$0.00\,\%$</td>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#ffffff;background:#5170cc;">nucleoplasm</span></td>
#         <td class='jLMnum'>124077</td>
#         <td class='jLMnum'>0.064 fl</td>
#         <td class='jLMnum'>30</td>
#         <td class='jLMnum'>0.784 µM</td>
#         <td class='jLMnum'>$0.00\,\%$</td>
#     </tr>
#     <tr>
#         <td><span class="jLMregion" style="color:#ffffff;background:#33467f;">abBoundary</span>
